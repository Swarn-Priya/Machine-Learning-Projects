# %% [markdown]
# # Book Recommendation System

# %%
import os,sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Books

# %%
books = pd.read_csv('C:\\Users\\Swarn\\Downloads\\Books (1).csv')
print(books.shape)
books.head(1)
# Out:
# (271360, 8)
#          ISBN           Book-Title         Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology  Mark P. O. Morford                2002
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...

# %%
books.isnull().sum()/len(books)*100
# Out:
# ISBN                   0.000000
# Book-Title             0.000000
# Book-Author            0.000369
# Year-Of-Publication    0.000000
# Publisher              0.000737
# Image-URL-S            0.000000
# Image-URL-M            0.000000
# Image-URL-L            0.001106
# dtype: float64

# %%
books.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Ratings

# %%
rating = pd.read_csv("C:\\Users\\Swarn\\Downloads\\Ratings (1).csv")
print(rating.shape)
rating.head(1)
# Out:
# (1149780, 3)
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0

# %%
rating.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
rating.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### User

# %%
user = pd.read_csv("C:\\Users\\Swarn\\Downloads\\Users (1).csv")
print(user.shape)
user.head(1)
# Out:
# (278858, 3)
#    User-ID            Location  Age
# 0        1  nyc, new york, usa  NaN

# %%
user.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
user.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Age will not impact in any which way...as it is a personal-content recommendation system and not popular based recommendation system. So we will delete the same.

# %%
user.drop(['Age'],axis=1,inplace=True)

# %%
print(user.shape)
user.head(1)
# Out:
# (278858, 2)
#    User-ID            Location
# 0        1  nyc, new york, usa

# %% [markdown]
# ### Merging all the Files

# %%
data = rating.merge(books,on="ISBN")
data.head(1)
# Out:
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose
#
#   Year-Of-Publication         Publisher  \
# 0                2002  Ballantine Books
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/034545104X.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/034545104X.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/034545104X.0...

# %%
data = user.merge(data,on='User-ID')
data.head(1)
# Out:
#    User-ID                   Location        ISBN  Book-Rating  \
# 0        2  stockton, california, usa  0195153448            0
#
#             Book-Title         Book-Author Year-Of-Publication  \
# 0  Classical Mythology  Mark P. O. Morford                2002
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...

# %% [markdown]
# ## Popularity Based Recommendation System

# %%
data['Book-Rating'].value_counts()
# Out:
# 0     647294
# 8      91804
# 10     71225
# 7      66402
# 9      60778
# 5      45355
# 6      31687
# 4       7617
# 3       5118
# 2       2375
# 1       1481
# Name: Book-Rating, dtype: int64

# %%
data.head(1)
# Out:
#    User-ID                   Location        ISBN  Book-Rating  \
# 0        2  stockton, california, usa  0195153448            0
#
#             Book-Title         Book-Author Year-Of-Publication  \
# 0  Classical Mythology  Mark P. O. Morford                2002
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...

# %%
rating_count = data.groupby(['Book-Title']).count()['Book-Rating'].reset_index()  
# we are going to take a count of ratings given for a particular book. 

rating_count.rename(columns = {'Book-Rating':'Count of Ratings'},inplace=True)  
rating_count.head()
# Out:
#                                           Book-Title  Count of Ratings
# 0   A Light in the Storm: The Civil War Diary of ...                 4
# 1                              Always Have Popsicles                 1
# 2               Apple Magic (The Collector's series)                 1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...                 1
# 4   Beyond IBM: Leadership Marketing and Finance ...                 1

# %%
rating_wise = data[["Book-Title","Book-Rating"]]
rating_wise.shape
# Out:
# (1031136, 2)

# %%
rat_mean = rating_wise.groupby('Book-Title').mean()
rat_mean.rename(columns={'Book-Rating':'Average-Ratings'},inplace=True)
rat_mean.head()
# Out:
#                                                     Average-Ratings
# Book-Title
#  A Light in the Storm: The Civil War Diary of A...             2.25
#  Always Have Popsicles                                         0.00
#  Apple Magic (The Collector's series)                          0.00
#  Ask Lily (Young Women of Faith: Lily Series, B...             8.00
#  Beyond IBM: Leadership Marketing and Finance f...             0.00

# %% [markdown]
# ### Merging the rating-count and rating mean files.

# %%
popular_books = rating_count.merge(rat_mean,on='Book-Title')
popular_books.head()
# Out:
#                                           Book-Title  Count of Ratings  \
# 0   A Light in the Storm: The Civil War Diary of ...                 4
# 1                              Always Have Popsicles                 1
# 2               Apple Magic (The Collector's series)                 1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...                 1
# 4   Beyond IBM: Leadership Marketing and Finance ...                 1
#
#    Average-Ratings
# 0             2.25
# 1             0.00
# 2             0.00
# 3             8.00
# 4             0.00

# %%
popular_books['Count of Ratings'].unique()
# Out:
# array([   4,    1,    2,   10,    9,   11,   17,    3,    5,   47,    8,
#           6,   12,   22,    7,   61,   13,   23,   37,   28,   65,   14,
#          20,  284,  509,   24,   25,   90,   21,   71,   57,  106,   30,
#         356,   85,  151,   16,   50,   31,  125,   41,   74,   44,   46,
#          32,   18,  136,   15,  346,   35,   29,   26,   38,  236,   27,
#         265,  156,   33,   52,   83,   67,   81,  139,   92,   54,  108,
#          39,  140,  116,   40,   42,   34,   48,  169,  104,   99,  302,
#         285,   86,  192,  109,   59,   75,  128,  174,  327,   19,   49,
#          36,   51,   66,  838,   68,  149,   64,   82,   63,   76,  413,
#          60,   56,  118,   78,   45,   95,   62,   43,   97,  135,  210,
#         549,   96,  101,  164,  205,  378,  273,   53,  158,  150,   70,
#          69,  279,  262,  121,  126,   77,  141,  332,  112,   84,  187,
#          58,  258,   55,  184,  147,  304,  110,   93,  114,   91,   72,
#          94,   80,  326,  222,  170,  670,  167,  233,   88,  142,  111,
#         160,   89,  248,  220,  230,   73,  107,  138,  181,  103,  247,
#          79,  276,  131,  195,  119,  229,  175,  178,  350,  191,  180,
#         102,  182,  207,  360,  263,  189,  201,  137,  165,  226,  155,
#         239,  815,  224,  171,  177,  193,  214,  198,   98,  143,  120,
#         287,  129,  344,  145,  249,  148,  152,  194,  311,  202,  228,
#         299,  183,  204,   87,  199,  122,  134,  176,  127,  130,  133,
#         293,  318,  740,  275,  481,  146,  203,  392,  123,  190,  209,
#         216,  115,  105,  161,  237,  409,  227,  321,  124,  254,  238,
#         225,  313,  231,  219,  257,  163,  526,  168,  490,  144,  468,
#         269,  556,  387,  347,  428,  278,  575,  162,  179,  154,  113,
#         200,  588,  309,  197,  260,  508,  372,  252,  100,  288,  153,
#         488,  117,  256,  157,  186,  664,  274,  166,  434,  259,  301,
#         457,  159,  496,  380,  291,  188,  362,  196,  335,  298,  283,
#         172,  277,  294,  242,  253,  244,  185,  402,  382,  364,  208,
#         446,  322,  662,  232,  374,  573,  241,  266,  435,  389,  132,
#         255,  384,  319,  443,  449,  393,  483,  314,  223,  898,  376,
#         368,  569,  430,  289,  336,  264,  268,  281,  507,  555,  458,
#         337,  312, 1295,  173,  828,  431,  650,  478,  581,  404,  568,
#         267,  494,  501,  466,  723,  308,  211,  520,  774,  212,  545,
#         655,  213,  617,  221,  552,  510,  493,  379,  342,  396,  585,
#         286, 2502,  234], dtype=int64)

# %%
popular_books = popular_books[popular_books['Count of Ratings']>50].sort_values(by="Average-Ratings",ascending=False)

# %%
popular_books.head()
# Out:
#                                                Book-Title  Count of Ratings  \
# 70396                                                Free                56
# 208575         The Stand (The Complete and Uncut Edition)                57
# 77812   Griffin &amp; Sabine: An Extraordinary Corresp...                72
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)               428
# 80422        Harry Potter and the Goblet of Fire (Book 4)               387
#
#         Average-Ratings
# 70396          8.017857
# 208575         6.175439
# 77812          6.041667
# 80434          5.852804
# 80422          5.824289

# %%
popular_books.shape
# Out:
# (2381, 3)

# %%
popular_books_final = popular_books.merge(books,on='Book-Title').drop_duplicates(subset='Book-Title')[['Book-Title',
                                                                                                      'Image-URL-S',
                                                                                                       'Image-URL-M',
                                                                                                       'Image-URL-L',
                                                                                                       'Count of Ratings',
                                                                                                       'Average-Ratings'
                                                                                                      ]]
print(popular_books_final.shape)
popular_books_final.duplicated().sum()
popular_books_final
popular_books_final
# Out:
# (2381, 6)
#                                              Book-Title  \
# 0                                                  Free
# 3            The Stand (The Complete and Uncut Edition)
# 4     Griffin &amp; Sabine: An Extraordinary Corresp...
# 5     Harry Potter and the Prisoner of Azkaban (Book 3)
# 8          Harry Potter and the Goblet of Fire (Book 4)
# ...                                                 ...
# 6942        Night Moves (Tom Clancy's Net Force, No. 3)
# 6945                                        Wild Animus
# 6946                                          Whirlwind
# 6948                                                Ssn
# 6949                             Ground Zero and Beyond
#
#                                             Image-URL-S  \
# 0     http://images.amazon.com/images/P/1844262553.0...
# 3     http://images.amazon.com/images/P/0385199570.0...
# 4     http://images.amazon.com/images/P/0877017883.0...
# 5     http://images.amazon.com/images/P/0439136350.0...
# 8     http://images.amazon.com/images/P/0439139597.0...
# ...                                                 ...
# 6942  http://images.amazon.com/images/P/042517400X.0...
# 6945  http://images.amazon.com/images/P/0971880107.0...
# 6946  http://images.amazon.com/images/P/0688066631.0...
# 6948  http://images.amazon.com/images/P/0425173534.0...
# 6949  http://images.amazon.com/images/P/1401088945.0...
#
#                                             Image-URL-M  \
# 0     http://images.amazon.com/images/P/1844262553.0...
# 3     http://images.amazon.com/images/P/0385199570.0...
# 4     http://images.amazon.com/images/P/0877017883.0...
# 5     http://images.amazon.com/images/P/0439136350.0...
# 8     http://images.amazon.com/images/P/0439139597.0...
# ...                                                 ...
# 6942  http://images.amazon.com/images/P/042517400X.0...
# 6945  http://images.amazon.com/images/P/0971880107.0...
# 6946  http://images.amazon.com/images/P/0688066631.0...
# 6948  http://images.amazon.com/images/P/0425173534.0...
# 6949  http://images.amazon.com/images/P/1401088945.0...
#
#                                             Image-URL-L  Count of Ratings  \
# 0     http://images.amazon.com/images/P/1844262553.0...                56
# 3     http://images.amazon.com/images/P/0385199570.0...                57
# 4     http://images.amazon.com/images/P/0877017883.0...                72
# 5     http://images.amazon.com/images/P/0439136350.0...               428
# 8     http://images.amazon.com/images/P/0439139597.0...               387
# ...                                                 ...               ...
# 6942  http://images.amazon.com/images/P/042517400X.0...                72
# 6945  http://images.amazon.com/images/P/0971880107.0...              2502
# 6946  http://images.amazon.com/images/P/0688066631.0...                61
# 6948  http://images.amazon.com/images/P/0425173534.0...                67
# 6949  http://images.amazon.com/images/P/1401088945.0...                68
#
#       Average-Ratings
# 0            8.017857
# 3            6.175439
# 4            6.041667
# 5            5.852804
# 8            5.824289
# ...               ...
# 6942         1.138889
# 6945         1.019584
# 6946         1.000000
# 6948         0.970149
# 6949         0.735294
#
# [2381 rows x 6 columns]

# %% [markdown]
# # TOP 15 -  most Popular Books

# %%
popular_books_final.head(15)
# Out:
#                                            Book-Title  \
# 0                                                Free
# 3          The Stand (The Complete and Uncut Edition)
# 4   Griffin &amp; Sabine: An Extraordinary Corresp...
# 5   Harry Potter and the Prisoner of Azkaban (Book 3)
# 8        Harry Potter and the Goblet of Fire (Book 4)
# 10                                  The Little Prince
# 15                                 The Cat in the Hat
# 17     Harry Potter and the Sorcerer's Stone (Book 1)
# 21                                         The Hobbit
# 33  Harry Potter and the Order of the Phoenix (Boo...
# 37  Sabine's Notebook: In Which the Extraordinary ...
# 38      Ender's Game (Ender Wiggins Saga (Paperback))
# 42  Fear and Loathing in Las Vegas : A Savage Jour...
# 43  Rich Dad, Poor Dad: What the Rich Teach Their ...
# 44            The Lord of the Rings (Movie Art Cover)
#
#                                           Image-URL-S  \
# 0   http://images.amazon.com/images/P/1844262553.0...
# 3   http://images.amazon.com/images/P/0385199570.0...
# 4   http://images.amazon.com/images/P/0877017883.0...
# 5   http://images.amazon.com/images/P/0439136350.0...
# 8   http://images.amazon.com/images/P/0439139597.0...
# 10  http://images.amazon.com/images/P/0156528207.0...
# 15  http://images.amazon.com/images/P/039480001X.0...
# 17  http://images.amazon.com/images/P/0590353403.0...
# 21  http://images.amazon.com/images/P/0345272579.0...
# 33  http://images.amazon.com/images/P/043935806X.0...
# 37  http://images.amazon.com/images/P/0811801802.0...
# 38  http://images.amazon.com/images/P/0312853238.0...
# 42  http://images.amazon.com/images/P/0679785892.0...
# 43  http://images.amazon.com/images/P/0446677450.0...
# 44  http://images.amazon.com/images/P/0618129022.0...
#
#                                           Image-URL-M  \
# 0   http://images.amazon.com/images/P/1844262553.0...
# 3   http://images.amazon.com/images/P/0385199570.0...
# 4   http://images.amazon.com/images/P/0877017883.0...
# 5   http://images.amazon.com/images/P/0439136350.0...
# 8   http://images.amazon.com/images/P/0439139597.0...
# 10  http://images.amazon.com/images/P/0156528207.0...
# 15  http://images.amazon.com/images/P/039480001X.0...
# 17  http://images.amazon.com/images/P/0590353403.0...
# 21  http://images.amazon.com/images/P/0345272579.0...
# 33  http://images.amazon.com/images/P/043935806X.0...
# 37  http://images.amazon.com/images/P/0811801802.0...
# 38  http://images.amazon.com/images/P/0312853238.0...
# 42  http://images.amazon.com/images/P/0679785892.0...
# 43  http://images.amazon.com/images/P/0446677450.0...
# 44  http://images.amazon.com/images/P/0618129022.0...
#
#                                           Image-URL-L  Count of Ratings  \
# 0   http://images.amazon.com/images/P/1844262553.0...                56
# 3   http://images.amazon.com/images/P/0385199570.0...                57
# 4   http://images.amazon.com/images/P/0877017883.0...                72
# 5   http://images.amazon.com/images/P/0439136350.0...               428
# 8   http://images.amazon.com/images/P/0439139597.0...               387
# 10  http://images.amazon.com/images/P/0156528207.0...               141
# 15  http://images.amazon.com/images/P/039480001X.0...                53
# 17  http://images.amazon.com/images/P/0590353403.0...               278
# 21  http://images.amazon.com/images/P/0345272579.0...                80
# 33  http://images.amazon.com/images/P/043935806X.0...               347
# 37  http://images.amazon.com/images/P/0811801802.0...                53
# 38  http://images.amazon.com/images/P/0312853238.0...               249
# 42  http://images.amazon.com/images/P/0679785892.0...                57
# 43  http://images.amazon.com/images/P/0446677450.0...                64
# 44  http://images.amazon.com/images/P/0618129022.0...                70
#
#     Average-Ratings
# 0          8.017857
# 3          6.175439
# 4          6.041667
# 5          5.852804
# 8          5.824289
# 10         5.815603
# 15         5.754717
# 17         5.737410
# 21         5.700000
# 33         5.501441
# 37         5.452830
# 38         5.409639
# 42         5.385965
# 43         5.359375
# 44         5.285714

# %% [markdown]
# # Collaboritive Based Recommendation System

# %% [markdown]
# we need to get the data in a format where user are columns and books are rows and the rating are the values. But we will only consider those users who are really readers and have read and shared feedback more than 200 times.

# %%
data.head(1)
data.shape
# Out:
# (1031136, 11)

# %% [markdown]
# 1. Get the data from user perspective -- only prime reader who have atleast reviewd 200 books.
# 2. Get the data from book rating perspective  --- books which have been in the review at least more than 50 times.
#
# User who have rated once or twice can't be very trustworthy.
# Similary books which have got 1/2 feedbacks may not be very popular or useful.
#
# #### Filtering data from User Perspective

# %%
df = data.groupby('User-ID').count()['Book-Rating']>200
prime_users = df[df].index

# %%
filtered_df = data[data['User-ID'].isin(prime_users)]
filtered_df.head(1)
# Out:
#      User-ID                     Location        ISBN  Book-Rating  \
# 311      254  minneapolis, minnesota, usa  0451167317            8
#
#         Book-Title   Book-Author Year-Of-Publication    Publisher  \
# 311  The Dark Half  Stephen King                1994  Signet Book
#
#                                            Image-URL-S  \
# 311  http://images.amazon.com/images/P/0451167317.0...
#
#                                            Image-URL-M  \
# 311  http://images.amazon.com/images/P/0451167317.0...
#
#                                            Image-URL-L
# 311  http://images.amazon.com/images/P/0451167317.0...

# %% [markdown]
# ##### Filtering using books rated - more than 50 times.

# %%
y = filtered_df.groupby("Book-Title").count()['Book-Rating'] >=50
famous_books = y[y].index   ###155845 count
famous_books
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Day Late and a Dollar Short', 'A Fine Balance',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Book-Title', length=706)

# %%
final_rating=filtered_df[filtered_df['Book-Title'].isin(famous_books)]
final_rating.shape
# Out:
# (58586, 11)

# %%
final_rating.drop_duplicates()
# Out:
#          User-ID                     Location        ISBN  Book-Rating  \
# 311          254  minneapolis, minnesota, usa  0451167317            8
# 312          254  minneapolis, minnesota, usa  043935806X            0
# 313          254  minneapolis, minnesota, usa  0804106304            0
# 314          254  minneapolis, minnesota, usa  0439064864            9
# 316          254  minneapolis, minnesota, usa  0671021001            7
# ...          ...                          ...         ...          ...
# 1029595   278418         omaha, nebraska, usa  0679425268            0
# 1029598   278418         omaha, nebraska, usa  0679448594            0
# 1029688   278418         omaha, nebraska, usa  0688042171            0
# 1030032   278418         omaha, nebraska, usa  0821759744            0
# 1030300   278418         omaha, nebraska, usa  1559029838            0
#
#                                                 Book-Title     Book-Author  \
# 311                                          The Dark Half    Stephen King
# 312      Harry Potter and the Order of the Phoenix (Boo...   J. K. Rowling
# 313                                      The Joy Luck Club         Amy Tan
# 314       Harry Potter and the Chamber of Secrets (Book 2)   J. K. Rowling
# 316                  She's Come Undone (Oprah's Book Club)      Wally Lamb
# ...                                                    ...             ...
# 1029595                                      Sole Survivor     DEAN KOONTZ
# 1029598                Primary Colors: A Novel of Politics       Anonymous
# 1029688                                  If Tomorrow Comes  Sidney Sheldon
# 1030032                                          Dangerous    Becky Barker
# 1030300                                   Call of the Wild     Jack London
#
#         Year-Of-Publication                          Publisher  \
# 311                    1994                        Signet Book
# 312                    2003                         Scholastic
# 313                    1994               Prentice Hall (K-12)
# 314                    1999                         Scholastic
# 316                    1998                             Pocket
# ...                     ...                                ...
# 1029595                1997                              Knopf
# 1029598                1996                   Random House Inc
# 1029688                1985       William Morrow &amp; Company
# 1030032                1997  Kensington Publishing Corporation
# 1030300                   0           Selldowns/no More Orders
#
#                                                Image-URL-S  \
# 311      http://images.amazon.com/images/P/0451167317.0...
# 312      http://images.amazon.com/images/P/043935806X.0...
# 313      http://images.amazon.com/images/P/0804106304.0...
# 314      http://images.amazon.com/images/P/0439064864.0...
# 316      http://images.amazon.com/images/P/0671021001.0...
# ...                                                    ...
# 1029595  http://images.amazon.com/images/P/0679425268.0...
# 1029598  http://images.amazon.com/images/P/0679448594.0...
# 1029688  http://images.amazon.com/images/P/0688042171.0...
# 1030032  http://images.amazon.com/images/P/0821759744.0...
# 1030300  http://images.amazon.com/images/P/1559029838.0...
#
#                                                Image-URL-M  \
# 311      http://images.amazon.com/images/P/0451167317.0...
# 312      http://images.amazon.com/images/P/043935806X.0...
# 313      http://images.amazon.com/images/P/0804106304.0...
# 314      http://images.amazon.com/images/P/0439064864.0...
# 316      http://images.amazon.com/images/P/0671021001.0...
# ...                                                    ...
# 1029595  http://images.amazon.com/images/P/0679425268.0...
# 1029598  http://images.amazon.com/images/P/0679448594.0...
# 1029688  http://images.amazon.com/images/P/0688042171.0...
# 1030032  http://images.amazon.com/images/P/0821759744.0...
# 1030300  http://images.amazon.com/images/P/1559029838.0...
#
#                                                Image-URL-L
# 311      http://images.amazon.com/images/P/0451167317.0...
# 312      http://images.amazon.com/images/P/043935806X.0...
# 313      http://images.amazon.com/images/P/0804106304.0...
# 314      http://images.amazon.com/images/P/0439064864.0...
# 316      http://images.amazon.com/images/P/0671021001.0...
# ...                                                    ...
# 1029595  http://images.amazon.com/images/P/0679425268.0...
# 1029598  http://images.amazon.com/images/P/0679448594.0...
# 1029688  http://images.amazon.com/images/P/0688042171.0...
# 1030032  http://images.amazon.com/images/P/0821759744.0...
# 1030300  http://images.amazon.com/images/P/1559029838.0...
#
# [58586 rows x 11 columns]

# %% [markdown]
# No duplicates. Data is ready.
#
# Now we just need to make the table x = books, y = users, value = ratings.

# %%
pt = final_rating.pivot_table(index='Book-Title',columns='User-ID',values = 'Book-Rating')

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             2977    3363    4017    \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     0.0     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             4385    6251    6323    \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     0.0     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     0.0     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             6543    ...  271705  \
# Book-Title                                                  ...
# 1984                                                   NaN  ...    10.0
# 1st to Die: A Novel                                    9.0  ...     NaN
# 2nd Chance                                             0.0  ...     NaN
# 4 Blondes                                              NaN  ...     NaN
# A Bend in the Road                                     NaN  ...     NaN
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     NaN
# You Belong To Me                                       NaN  ...     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN  ...     NaN
# Zoya                                                   NaN  ...     NaN
# \O\" Is for Outlaw"                                    NaN  ...     NaN
#
# User-ID                                             273979  274004  274061  \
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        9.0     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   0.0     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# User-ID                                             274301  274308  275970  \
# Book-Title
# 1984                                                   NaN     NaN     0.0
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     0.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     0.0
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     0.0
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    8.0     NaN     NaN
#
# User-ID                                             277427  277639  278418
# Book-Title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     0.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# [706 rows x 810 columns]

# %%
pt.fillna(0,inplace=True)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_score = cosine_similarity(pt)

# %%
similarity_score.shape  ## 706*706 matrix is created for all the books.
# Out:
# (706, 706)

# %%
def recommend(books):
    ### fetching the index
    index = np.where(pt.index==books)[0][0]
    similar_books = sorted(list(enumerate(similarity_score[index])),reverse=True,key = lambda x:x[1])[1:6]
    
    for i in similar_books:
            print(pt.index[i[0]])
    
#     return suggestions

# %%
recommend('The Dark Half')
# Out:
# The Tommyknockers
# Gerald's Game
# Four Past Midnight
# Skeleton Crew
# Insomnia

# %%
recommend("You Belong To Me")
# Out:
# Loves Music, Loves to Dance
# I'll Be Seeing You
# Before I Say Good-Bye
# Daddy's Little Girl
# All Around the Town

# %% [markdown]
# # Done
