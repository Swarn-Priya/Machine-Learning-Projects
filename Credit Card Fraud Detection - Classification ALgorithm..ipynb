# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("E:\\LEARNBAY\\Projects\\creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# ## Preprocessing Data

# %%
# 1. missing data

df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# 2. Handling outliers

df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  3.918649e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  5.682686e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -8.761736e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.811118e-15      1.415869   -5.683171     -0.848640
# V5      284807.0 -1.552103e-15      1.380247 -113.743307     -0.691597
# V6      284807.0  2.040130e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -1.698953e-15      1.237094  -43.557242     -0.554076
# V8      284807.0 -1.893285e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -3.147640e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  1.772925e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  9.289524e-16      1.020713   -4.797473     -0.762494
# ...

# %%
# 3. Handling encoding

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# 4. Handling Imbalance Dataset

df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# 1. No missing data
# 2. No outliers as such. (AMount is going to be high)
# 3. all the features are already in numeric form. Not required.
# 4. Dataset is imbalanced and needs to be balanced but this will be done only once the model is built and accuracy is checked.
# 5. Feature Scaling -- It need to be done post EDA step as the anount column is very high as compared to other columns.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
for i in df.columns:
    sns.distplot(df[i])
    plt.show()

# %%
# sns.pairplot(df)   --- taking a lot of time. 
plt.show()

# %%
plt.figure(figsize=(18,18))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
# Spliting the Data

x = df.iloc[:,0:-1]
y = df['Class']

# %%
x.head(1)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
#
#          V8        V9  ...       V20       V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...  0.251412 -0.018307  0.277838 -0.110474  0.066928
#
#         V25       V26       V27       V28  Amount
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62
#
# [1 rows x 30 columns]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
# Feature SCaling

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
scx = sc.fit_transform(x)
scx
# Out:
# array([[-1.99658302, -0.69424232, -0.04407492, ...,  0.33089162,
#         -0.06378115,  0.24496426],
#        [-1.99658302,  0.60849633,  0.16117592, ..., -0.02225568,
#          0.04460752, -0.34247454],
#        [-1.99656197, -0.69350046, -0.81157783, ..., -0.13713686,
#         -0.18102083,  1.16068593],
#        ...,
#        [ 1.6419735 ,  0.98002374, -0.18243372, ...,  0.01103672,
#         -0.0804672 , -0.0818393 ],
#        [ 1.6419735 , -0.12275539,  0.32125034, ...,  0.26960398,
#          0.31668678, -0.31324853],
#        [ 1.64205773, -0.27233093, -0.11489898, ..., -0.00598394,
#          0.04134999,  0.51435531]])

# %%
# Train and Test SPlit

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state = 101)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (227845, 30) (56962, 30) (227845,) (56962,)

# %% [markdown]
# ### MOdel BUilding

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
Mlist = {'LogisticRegression':LogisticRegression(),
         'DecisionTreeClassifier':DecisionTreeClassifier(criterion='gini'),
         'RandomForestClassifier':RandomForestClassifier(n_estimators=100),
#          'KNeighborsClassifier':KNeighborsClassifier(n_neighbors=5),
#          'SVC':SVC(),
         'AdaBoostClassifier':AdaBoostClassifier(learning_rate=0.001),
#          'GradientBoostingClassifier': GradientBoostingClassifier(learning_rate=0.001),
#          'XGBClassifier' : XGBClassifier(learning_rate=0.001)
        }

# %%
# TO Calculate the best n_neighbor size...but taking too much time. Sonot executing it at this momnet.

# error_rate = []

# for i in range(2,15):
#     knn =  KNeighborsClassifier(n_neighbors=i)
#     knn.fit(x_train,y_train)
#     y_pred=knn.predict(x_test)
#     error_rate.append(np.mean(y_pred != y_test))

# %%
for name,modl in Mlist.items():
    name=modl
    name.fit(x_train,y_train)
    y_pred_test=name.predict(x_test)
    y_pred_train = name.predict(x_train)
    print("*"*3,name,"*"*3)
    #Accurcy Score
    print("Accuracy Score Train - ",accuracy_score(y_train,y_pred_train))
    print("Accuracy Score Test - ",accuracy_score(y_test,y_pred_test))
    print(classification_report(y_train,y_pred_train))
    print(classification_report(y_test,y_pred_test))
    print(confusion_matrix(y_train,y_pred_train))
    print(confusion_matrix(y_test,y_pred_test))
    print("________________________"*3)
# Out:
# *** LogisticRegression() ***
# Accuracy Score Train -  0.998977374969826
# Accuracy Score Test -  0.9990695551420246
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    227456
#            1       0.70      0.71      0.70       389
#
#     accuracy                           1.00    227845
#    macro avg       0.85      0.85      0.85    227845
# weighted avg       1.00      1.00      1.00    227845
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56859
#            1       0.75      0.73      0.74       103
#
#     accuracy                           1.00     56962
#    macro avg       0.87      0.86      0.87     56962
# weighted avg       1.00      1.00      1.00     56962
#
# [[227336    120]
#  [   113    276]]
# [[56834    25]
#  [   28    75]]
# ________________________________________________________________________
# *** DecisionTreeClassifier() ***
# ...

# %%
*** LogisticRegression() ***
Accuracy Score Train -  0.998977374969826
Accuracy Score Test -  0.9990695551420246

*** DecisionTreeClassifier() ***
Accuracy Score Train -  1.0
Accuracy Score Test -  0.9989642217618764

*** RandomForestClassifier() ***
Accuracy Score Train -  1.0
Accuracy Score Test -  0.9995962220427653

*** AdaBoostClassifier(learning_rate=0.001) ***
Accuracy Score Train -  0.9990827097368825
Accuracy Score Test -  0.9991222218320986


Model Looks to be very nice. IT is not showing any variance or bias. But this result may be wrong as the dataset was imbalanced.
So let us balance the dataset and rerun the model again. m

# %% [markdown]
# # BALANCING DATASET

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
import imblearn
from imblearn.over_sampling import SMOTE

smote = SMOTE()
x_resample,y_resample = smote.fit_resample(x,y)

# %%
print(x_resample.shape,y_resample.shape)
print(x.shape,y.shape)
# Out:
# (568630, 30) (568630,)
# (284807, 30) (284807,)

# %%
scx = sc.fit_transform(x_resample)
# scx
xr_train,xr_test,yr_train,yr_test = train_test_split(x_resample,y_resample,test_size=0.2,random_state = 101)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
print("Resampled data - ",xr_train.shape,xr_test.shape,yr_train.shape,yr_test.shape)
# Out:
# (227845, 30) (56962, 30) (227845,) (56962,)
# Resampled data -  (454904, 30) (113726, 30) (454904,) (113726,)

# %%
for name,modl in Mlist.items():
    name=modl
    name.fit(xr_train,yr_train)
    y_pred_test=name.predict(xr_test)
    y_pred_train = name.predict(xr_train)
    print("*"*3,name,"*"*3)
    #Accurcy Score
    print("Accuracy Score Train - ",accuracy_score(yr_train,y_pred_train))
    print("Accuracy Score Test - ",accuracy_score(yr_test,y_pred_test))
    print(classification_report(yr_train,y_pred_train))
    print(classification_report(yr_test,y_pred_test))
    print(confusion_matrix(yr_train,y_pred_train))
    print(confusion_matrix(yr_test,y_pred_test))
    print("________________________"*3)
# Out:
# *** LogisticRegression() ***
# Accuracy Score Train -  0.9733482229217593
# Accuracy Score Test -  0.9745968380141744
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97    227388
#            1       0.98      0.96      0.97    227516
#
#     accuracy                           0.97    454904
#    macro avg       0.97      0.97      0.97    454904
# weighted avg       0.97      0.97      0.97    454904
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     56927
#            1       0.98      0.97      0.97     56799
#
#     accuracy                           0.97    113726
#    macro avg       0.97      0.97      0.97    113726
# weighted avg       0.97      0.97      0.97    113726
#
# [[223453   3935]
#  [  8189 219327]]
# [[55994   933]
#  [ 1956 54843]]
# ________________________________________________________________________
# *** DecisionTreeClassifier() ***
# ...

# %% [markdown]
# *** LogisticRegression() ***
# Accuracy Score Train -  0.9733482229217593
# Accuracy Score Test -  0.9745968380141744
#
# *** DecisionTreeClassifier() ***
# Accuracy Score Train -  1.0
# Accuracy Score Test -  0.9985931097550252
#
# *** RandomForestClassifier() ***
# Accuracy Score Train -  1.0
# Accuracy Score Test -  0.9999120693596891
#
# *** AdaBoostClassifier(learning_rate=0.001) ***
# Accuracy Score Train -  0.9464612313806869
# Accuracy Score Test -  0.9466964458435186
#
#
# SCore is good..no bias and no varaince is seen.
# No overfitting and no underfitting.

# %% [markdown]
# # DONE
